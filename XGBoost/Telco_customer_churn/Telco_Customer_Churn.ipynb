# %%
import pandas as pd #load and manipulate data and for OneHotEncoding
import numpy as np #calculate mean and sd
from sklearn.model_selection import train_test_split, GridSearchCV #split data, cross validation
from sklearn.metrics import balanced_accuracy_score, roc_auc_score, make_scorer, confusion_matrix
import xgboost as xgb

# %% [markdown]
# * Importing data
#
# -> Missing Data
#
# * Identifying Missing Data
# * Dealing with Missing data
#
#
# -> Formatting Data
# * Splitting data into dependent and independent variable
# * OHE
# * Converting columns to int, float or bool
#
# -> Building Preliminary XGBoost Model
#
# -> Optimizing Parameters with cross validation and GridSearch()
#
# -> Building, Drawing, Interpreting and Evaluating Optimized XGBoost

# %%
df = pd.read_csv('telco.csv')

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
df.drop(["Churn Label", "Churn Score", "CLTV", "Churn Reason"], axis = 1, inplace=True) #set axis=0 to remove rows, axis=1 to remove columns
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...
#
#   Device Protection Tech Support Streaming TV  Streaming Movies  \
# 0                No           No           No                No
# ...

# %%
df["Count"].unique()
# Out:
# array([1])

# %%
df["Country"].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df["State"].unique()
# Out:
# array(['California'], dtype=object)

# %%
df.City.unique()
# Out:
# array(['Los Angeles', 'Beverly Hills', 'Huntington Park', ..., 'Standish',
#        'Tulelake', 'Olympic Valley'], dtype=object)

# %%
df.drop(["CustomerID", "Count", "Country", "State", "Lat Long"], axis=1, inplace=True)
df.head()
# Out:
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service  ... Device Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# ...

# %%
#need to remove whitespace in "City" column as it is not allowed to have them for drawing a tree.
df["City"].replace(" ", "_", regex= True, inplace = True)
df.head()
# Out:
# C:\Users\a812616\AppData\Local\Temp\ipykernel_15192\2098320226.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["City"].replace(" ", "_", regex= True, inplace = True)
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# ...

# %%
df.columns = df.columns.str.replace(" ", "_")
df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %% [markdown]
# * Deal with Missing Data

# %% [markdown]
# XGBoost has a default behavior for missing data. So, after identifying missing data, set them to 0.

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges         object
# Churn_Value            int64
# dtype: object

# %%
df["Phone_Service"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df["Total_Charges"].unique()
# Out:
# array(['108.15', '151.65', '820.5', ..., '7362.9', '346.45', '6844.5'],
#       dtype=object)

# %%
len(df.loc[df["Total_Charges"] == ' '])
# Out:
# 11

# %%
df.loc[df["Total_Charges"] == ' ']
# Out:
#                 City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 2234  San_Bernardino     92408  34.084909 -117.258107  Female             No
# 2438    Independence     93526  36.869584 -118.189241    Male             No
# 2568       San_Mateo     94401  37.590421 -122.306467  Female             No
# 2667       Cupertino     95014  37.306612 -122.080621    Male             No
# 2856        Redcrest     95569  40.363446 -123.835041  Female             No
# 4331     Los_Angeles     90029  34.089953 -118.294824    Male             No
# 4687        Sun_City     92585  33.739412 -117.173334    Male             No
# 5104      Ben_Lomond     95005  37.078873 -122.090386  Female             No
# 5719        La_Verne     91750  34.144703 -117.770299    Male             No
# 6772            Bell     90201  33.970343 -118.171368  Female             No
# 6840      Wilmington     90744  33.782068 -118.262263    Male             No
#
# ...

# %%
df.loc[(df["Total_Charges"] == ' '), "Total_Charges"] = 0

# %%
df.loc[df["Tenure_Months"] == 0]
# Out:
#                 City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 2234  San_Bernardino     92408  34.084909 -117.258107  Female             No
# 2438    Independence     93526  36.869584 -118.189241    Male             No
# 2568       San_Mateo     94401  37.590421 -122.306467  Female             No
# 2667       Cupertino     95014  37.306612 -122.080621    Male             No
# 2856        Redcrest     95569  40.363446 -123.835041  Female             No
# 4331     Los_Angeles     90029  34.089953 -118.294824    Male             No
# 4687        Sun_City     92585  33.739412 -117.173334    Male             No
# 5104      Ben_Lomond     95005  37.078873 -122.090386  Female             No
# 5719        La_Verne     91750  34.144703 -117.770299    Male             No
# 6772            Bell     90201  33.970343 -118.171368  Female             No
# 6840      Wilmington     90744  33.782068 -118.262263    Male             No
#
# ...

# %%
df["Total_Charges"] = pd.to_numeric(df["Total_Charges"])
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges        float64
# Churn_Value            int64
# dtype: object

# %%
df.replace(" ", "_", regex=True, inplace=True) #to replace whitespaces in all columns with underscores
df.head() #the reason for replacing whitespaces is to print out a nice tree
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %% [markdown]
# #Format Data

# %%
X = df.drop("Churn_Value", axis=1).copy()
X.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Online_Backup  \
# 0      No         No              2           Yes  ...           Yes
# 1      No        Yes              2           Yes  ...            No
# 2      No        Yes              8           Yes  ...            No
# 3     Yes        Yes             28           Yes  ...            No
# 4      No        Yes             49           Yes  ...           Yes
#
#   Device_Protection Tech_Support Streaming_TV Streaming_Movies  \
# ...

# %%
y = df["Churn_Value"].copy()
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Churn_Value, dtype: int64

# %% [markdown]
# #Format - OHE (Convert columns of categorical data into multiple columns of binary values)
# Bcoz XGBoost natively supports continuous data, and it does not natively supports categorical data

# %%
X_encoded = pd.get_dummies(X, columns=["City", "Gender",
                           "Partner",
                           "Dependents",
                           "Phone_Service",
                           "Multiple_Lines",
                           "Internet_Service",
                           "Online_Security",
                           "Online_Backup",
                           "Device_Protection",
                           "Tech_Support",
                           "Streaming_TV",
                           "Streaming_Movies",
                           "Contract",
                           "Senior_Citizen",
                           "Paperless_Billing",
                           "Payment_Method"], dtype=int) #this encoding not good for linear or logistic regression

# %%
X_encoded.head()
# Out:
#    Zip_Code   Latitude   Longitude  Tenure_Months  Monthly_Charges  \
# 0     90003  33.964131 -118.272783              2            53.85
# 1     90005  34.059281 -118.307420              2            70.70
# 2     90006  34.048013 -118.293953              8            99.65
# 3     90010  34.062125 -118.315709             28           104.80
# 4     90015  34.039224 -118.266293             49           103.70
#
#    Total_Charges  City_Acampo  City_Acton  City_Adelanto  City_Adin  ...  \
# 0         108.15            0           0              0          0  ...
# 1         151.65            0           0              0          0  ...
# 2         820.50            0           0              0          0  ...
# 3        3046.05            0           0              0          0  ...
# 4        5036.30            0           0              0          0  ...
#
#    Contract_One_year  Contract_Two_year  Senior_Citizen_No  \
# 0                  0                  0                  1
# ...

# %%
X_encoded.dtypes
# Out:
# Zip_Code                                      int64
# Latitude                                    float64
# Longitude                                   float64
# Tenure_Months                                 int64
# Monthly_Charges                             float64
#                                              ...
# Paperless_Billing_Yes                         int64
# Payment_Method_Bank_transfer_(automatic)      int64
# Payment_Method_Credit_card_(automatic)        int64
# Payment_Method_Electronic_check               int64
# Payment_Method_Mailed_check                   int64
# Length: 1178, dtype: object

# %%
y.unique()
# Out:
# array([1, 0])

# %% [markdown]
# XGBoost uses sparse matrix to store values, and hence is efficient to deal with missing data value entered as 0

# %% [markdown]
# XGBoost Model

# %%
sum(y)/len(y)
# Out:
# 0.2653698707936959

# %% [markdown]
# Since only ~27% people have left the company, this is an imbalanced dataset. Hence, we use stratification in order to maintain the same percentage of people who left the company in both training and testing set

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, random_state=42, stratify=y)

# %%
sum(y_train)/len(y_train)
# Out:
# 0.2654297614539947

# %%
sum(y_test)/len(y_test)
# Out:
# 0.26519023282226006

# %%
clf_xgb = xgb.XGBClassifier(objective="binary:logistic", missing = np.nan, seed = 42, 
                            eval_metrics = 'aucpr', early_stopping_rounds=10)
#If the evaluation metric does not improve for a specified number of consecutive rounds (early_stopping_rounds),
#training stops early.
clf_xgb.fit(X_train, y_train,
            verbose = True,    
            eval_set = [(X_test, y_test)])
# Out:
# [0]	validation_0-logloss:0.49829
# [1]	validation_0-logloss:0.46265
# [2]	validation_0-logloss:0.43733
# [3]	validation_0-logloss:0.42431
# [4]	validation_0-logloss:0.41539
# c:\Users\a812616\AppData\Local\anaconda3\Lib\site-packages\xgboost\callback.py:386: UserWarning: [14:15:01] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "eval_metrics" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [5]	validation_0-logloss:0.41088
# [6]	validation_0-logloss:0.40627
# [7]	validation_0-logloss:0.40522
# [8]	validation_0-logloss:0.40473
# [9]	validation_0-logloss:0.40339
# [10]	validation_0-logloss:0.40169
# [11]	validation_0-logloss:0.40309
# [12]	validation_0-logloss:0.40037
# [13]	validation_0-logloss:0.40206
# [14]	validation_0-logloss:0.40291
# [15]	validation_0-logloss:0.40308
# [16]	validation_0-logloss:0.40401
# [17]	validation_0-logloss:0.40466
# [18]	validation_0-logloss:0.40559
# [19]	validation_0-logloss:0.40539
# ...

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_estimator(clf_xgb, X_test,y_test, display_labels=["Did not Leave", "Left"])

# %% [markdown]
# XGboost predicted only 51% correctly among those who left the company. But we need prediction to be higher %. Parameter 'scale_pos_weight' helps with imbalanced data. Cross validation helps to optimize parameters.
